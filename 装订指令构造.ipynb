# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy import signal
import time
import datetime
import serial
from scipy.fftpack import fft,ifft
from matplotlib.pylab import mpl
import struct
import os
import serial
import binascii
from fun_chy2 import *

mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 14
#      12 import serial
#      13 import binascii
# ---> 14 from fun_chy2 import *
#      16 mpl.rcParams['font.sans-serif'] = ['SimHei']
#      17 mpl.rcParams['axes.unicode_minus'] = False
#
# ModuleNotFoundError: No module named 'fun_chy2'

# %%
# !python.exe -m PyQt5.uic.pyuic Automated_testingV2.0.ui -o Automated_testingV20.py

# %%
# !python.exe -m PyQt5.uic.pyuic Automated_testingV1.5.ui -o Automated_testingV15.py

# %%
# !python.exe -m PyQt5.uic.pyuic sample_testingV1.32.ui -o sample_testingV13.py

# %%
# !python.exe -m PyQt5.uic.pyuic sample_testingV1.3.ui -o sample_testingV13.py
# Out:
# Error: No such file or directory: "sample_testingV1.3.ui"

# %%
# !python.exe -m PyQt5.uic.pyuic Automated_testingV1.7.ui -o Automated_testingV17.py

# %%
input_data = '1 2 3'
input_data.split(r'[\s,，]+')
# Out:
# ['1', '2', '3']

# %%
f1 = '129#05_slsBD_BD1#loc[0.0_0.0_0.0_0.0]#20250604112712_s.txt'
f2 = '129#05_slsBD_BD16#spd[0.0_0.0_0.0_30.0]#20250604112712_s.txt'
f3 = 'test'
pattern = r'(?:loc|spd)\[([^\]]+)\]'
import re
print(re.search(pattern, f1).group(1))
print(re.search(pattern, f2).group(1))
print(re.search(pattern, f3).group(1))
# Out:
# 0.0_0.0_0.0_0.0
# 0.0_0.0_0.0_30.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 8
#       6 print(re.search(pattern, f1).group(1))
#       7 print(re.search(pattern, f2).group(1))
# ----> 8 print(re.search(pattern, f3).group(1))
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
$GNRMC,085120.00,A,3114.12345,N,12128.54321,E,1.25,185.36,160726,,,A*6F
$GNHDT,123.45,T*1F
